# %%
import SimpleITK as sitk
import numpy as np
import os

def normalize_one_volume(volume):
    new_volume = np.zeros(volume.shape)
    location = np.where(volume != 0)
    mean = np.mean(volume[location])
    var = np.std(volume[location])
    new_volume[location] = (volume[location] - mean) / var

    return new_volume

def merge_volumes(*volumes):
    return np.stack(volumes, axis=0)
    
def get_volume(root, patient, desired_depth,
              desired_height, desired_width,
              normalize_flag, 
              flip=0):
    flair_suffix = "_flair.nii.gz"
    t1_suffix = "_t1.nii.gz"
    t1ce_suffix = "_t1ce.nii.gz"
    t2_suffix = "_t2.nii.gz"
    
    path_flair = os.path.join(root, patient, patient + flair_suffix)
    path_t1 = os.path.join(root, patient, patient + t1_suffix)
    path_t2 = os.path.join(root, patient, patient + t2_suffix)
    path_t1ce = os.path.join(root, patient, patient + t1ce_suffix)
    
    flair = sitk.GetArrayFromImage(sitk.ReadImage(path_flair))
    t1 = sitk.GetArrayFromImage(sitk.ReadImage(path_t1))
    t2 = sitk.GetArrayFromImage(sitk.ReadImage(path_t2))
    t1ce = sitk.GetArrayFromImage(sitk.ReadImage(path_t1ce))

    if desired_depth > 155:
        flair = np.concatenate([flair, np.zeros((desired_depth - 155, 240, 240))], axis=0)
        t1 = np.concatenate([t1, np.zeros((desired_depth - 155, 240, 240))], axis=0)
        t2 = np.concatenate([t2, np.zeros((desired_depth - 155, 240, 240))], axis=0)
        t1ce = np.concatenate([t1ce, np.zeros((desired_depth - 155, 240, 240))], axis=0)

    if normalize_flag == True:
        out = merge_volumes(normalize_one_volume(flair), normalize_one_volume(t2), normalize_one_volume(t1ce), 
                            normalize_one_volume(t1))
    else:
        out = merge_volumes(flair, t2, t1ce, t1)
    
    if flip == 1:
        out = out[:, ::-1, :, :]
    elif flip == 2:
        out = out[:, :, ::-1, :]
    elif flip == 3:
        out = out[:, :, :, ::-1]
    elif flip == 4:
        out = out[:, :, ::-1, ::-1]
    elif flip == 5:
        out = out[:, ::-1, ::-1, ::-1]
    
    return np.expand_dims(out, axis=0)

# %%
import sys
import numpy as np
sys.path.remove('/home/sentic/.local/lib/python3.6/site-packages')

import torch
torch.backends.cudnn.benchmark=True

device_id = 0
torch.cuda.set_device(device_id)

root = "/home/sentic/MICCAI/data/train/"
use_gpu = True
n_epochs = 300
batch_size = 1
use_amp = False
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import LambdaLR

from torch.utils.data import DataLoader

from model import LargeCascadedModel
from dataset import BraTS
from losses import DiceLoss, DiceLossLoss
from tqdm import tqdm_notebook, tqdm
paths_model = ["./checkpoints/checkpoint_190.pt", "./checkpoints/checkpoint_191.pt", "./checkpoints/checkpoint_192.pt",
              "./checkpoints/checkpoint_193.pt", "./checkpoints/checkpoint_194.pt", "./checkpoints/checkpoint_195.pt",
              "./checkpoints/checkpoint_196.pt", "./checkpoints/checkpoint_197.pt", "./checkpoints/checkpoint_198.pt",
              "./checkpoints/checkpoint_199.pt"]
diceLoss = DiceLossLoss()

# %%
intresting_patients = ['BraTS20_Validation_067', 'BraTS20_Validation_068', 'BraTS20_Validation_069', 'BraTS20_Validation_072',
                      'BraTS20_Validation_083', 'BraTS20_Validation_077', 'BraTS20_Validation_076', 'BraTS20_Validation_074',
                      'BraTS20_Validation_085', 'BraTS20_Validation_087', 'BraTS20_Validation_088', 'BraTS20_Validation_089',
                      'BraTS20_Validation_091', 'BraTS20_Validation_092', 'BraTS20_Validation_099', 'BraTS20_Validation_103']


patients_path = "/home/sentic/MICCAI/data/train/"
for patient_name in tqdm(os.listdir(patients_path)):
    if patient_name.startswith('BraTS'):
        output = np.zeros((3, 155, 240, 240))
        
        for path_model in paths_model:
            model = LargeCascadedModel(inplanes_encoder_1=4, channels_encoder_1=16, num_classes_1=3,
                           inplanes_encoder_2=7, channels_encoder_2=32, num_classes_2=3)
            model.load_state_dict(torch.load(path_model, map_location='cuda:0')['state_dict'])
            if use_gpu:
                model = model.to("cuda")

            model.eval()
            
            with torch.no_grad():
                for flip in range(0, 6):
                    volume = get_volume(patients_path, patient_name, 160, 240, 240, True, flip)
                    volume = torch.FloatTensor(volume.copy())
                    if use_gpu:
                        volume = volume.to("cuda")
                    _, _, decoded_region3, _ = model(volume)
                    decoded_region3 = decoded_region3.detach().cpu().numpy()
                    decoded_region3 = decoded_region3.squeeze()
                    if flip == 1:
                        decoded_region3 = decoded_region3[:, ::-1, :, :]
                    elif flip == 2:
                        decoded_region3 = decoded_region3[:, :, ::-1, :]
                    elif flip == 3:
                        decoded_region3 = decoded_region3[:, :, :, ::-1]
                    elif flip == 4:
                        decoded_region3 = decoded_region3[:, :, ::-1, ::-1]
                    elif flip == 5:
                        decoded_region3 = decoded_region3[:, ::-1, ::-1, ::-1]

                    output += decoded_region3[:, :155, :, :]

        np_array = output
        np_array = np_array / (6.0 * 10.0)

        np.save("./val_masks_np/" + patient_name + ".np", np_array)
# Out:
# 100%|██████████| 371/371 [13:16:08<00:00, 128.76s/it]

# %%
import os
import numpy as np
import SimpleITK as sitk

threshold_wt = 0.7
threshold_tc = 0.6
threshold_et = 0.7
low_threshold_et = 0.6
threshold_num_pixels_et = 150

patients_path = "/home/sentic/MICCAI/data/train/"
intresting_patients = ['BraTS20_Validation_067', 'BraTS20_Validation_068', 'BraTS20_Validation_069', 'BraTS20_Validation_072',
                      'BraTS20_Validation_083', 'BraTS20_Validation_077', 'BraTS20_Validation_076', 'BraTS20_Validation_074',
                      'BraTS20_Validation_085', 'BraTS20_Validation_087', 'BraTS20_Validation_088', 'BraTS20_Validation_089',
                      'BraTS20_Validation_091', 'BraTS20_Validation_092', 'BraTS20_Validation_099', 'BraTS20_Validation_103']


for patient_name in os.listdir(patients_path):
    if patient_name.startswith('BraTS'):
        path_big_volume = os.path.join(patients_path, patient_name, patient_name + "_flair.nii.gz")
        np_array = np.load("./val_masks_np/" + patient_name + ".np.npy")
        image = sitk.ReadImage(path_big_volume)
        direction = image.GetDirection()
        spacing = image.GetSpacing()
        origin = image.GetOrigin()

        seg_image = np.zeros((155, 240, 240))
        label_1 = np_array[2, :, :, :] # where the enhanced tumor is
        location_pixels_et = np.where(label_1 >= threshold_et)
        num_pixels_et = location_pixels_et[0].shape[0]
        label_2 = np_array[1, :, :, :] # locatia 1-urilor si 4-urilor
        label_3 = np_array[0, :, :, :] # locatia 1 + 2 + 4

        if patient_name in intresting_patients:
            print(patient_name, "--->", num_pixels_et)
        else:
            print(patient_name, "***->", num_pixels_et)

        if num_pixels_et > threshold_num_pixels_et: # if there are at least num of pixels
            label_1[label_1 >= threshold_et] = 1 # put them in et category
        else:
            label_1[label_1 >= threshold_et] = 0 # don't put them
            label_2[location_pixels_et] = 1 # but put them on tumor core

        label_2[(label_1 < threshold_et) & (label_1 >= low_threshold_et)] = 1

        label_1[label_1 < threshold_et] = 0
        location_1 = np.where(label_1 != 0)
        seg_image[location_1] = 4

        label_2[label_2 >= threshold_tc] = 1
        label_2[label_2 < threshold_tc] = 0
        location_2 = np.where((label_2 != 0) & (label_1 == 0))
        seg_image[location_2] = 1


        label_3[label_3 >= threshold_wt] = 1
        label_3[label_3 < threshold_wt] = 0
        location_3 = np.where((label_3 != 0) & (label_2 == 0))
        seg_image[location_3] = 2

        out_image = sitk.GetImageFromArray(seg_image)
        out_image.SetDirection(direction)
        out_image.SetSpacing(spacing)
        out_image.SetOrigin(origin)

        sitk.WriteImage(out_image, os.path.join("./final_masks", patient_name + ".nii.gz"))
# Out:
# BraTS20_Training_178 ***-> 45141
# BraTS20_Training_202 ***-> 23822
# BraTS20_Training_201 ***-> 29321
# BraTS20_Training_284 ***-> 2501
# BraTS20_Training_300 ***-> 964
# BraTS20_Training_189 ***-> 20474
# BraTS20_Training_124 ***-> 39207
# BraTS20_Training_118 ***-> 7987
# BraTS20_Training_283 ***-> 10327
# BraTS20_Training_196 ***-> 38012
# BraTS20_Training_148 ***-> 16934
# BraTS20_Training_141 ***-> 526
# BraTS20_Training_130 ***-> 33760
# BraTS20_Training_014 ***-> 19049
# BraTS20_Training_340 ***-> 29587
# BraTS20_Training_215 ***-> 24154
# BraTS20_Training_062 ***-> 34123
# BraTS20_Training_095 ***-> 17780
# BraTS20_Training_057 ***-> 7855
# BraTS20_Training_204 ***-> 8566
# BraTS20_Training_094 ***-> 934
# BraTS20_Training_266 ***-> 126
# BraTS20_Training_047 ***-> 31243
# BraTS20_Training_149 ***-> 60544
# BraTS20_Training_209 ***-> 19756
# BraTS20_Training_067 ***-> 34527
# BraTS20_Training_282 ***-> 6863
# BraTS20_Training_354 ***-> 57606
# BraTS20_Training_352 ***-> 8302
# BraTS20_Training_342 ***-> 50681
# BraTS20_Training_127 ***-> 5932
# BraTS20_Training_022 ***-> 16797
# BraTS20_Training_083 ***-> 6722
# BraTS20_Training_188 ***-> 6039
# BraTS20_Training_280 ***-> 621
# BraTS20_Training_288 ***-> 15677
# BraTS20_Training_336 ***-> 29031
# BraTS20_Training_111 ***-> 16213
# BraTS20_Training_063 ***-> 2136
# BraTS20_Training_230 ***-> 14822
# BraTS20_Training_117 ***-> 9651
# BraTS20_Training_104 ***-> 34220
# BraTS20_Training_180 ***-> 64531
# BraTS20_Training_176 ***-> 3626
# BraTS20_Training_066 ***-> 8284
# BraTS20_Training_243 ***-> 11353
# BraTS20_Training_260 ***-> 17519
# BraTS20_Training_085 ***-> 4291
# BraTS20_Training_051 ***-> 11864
# BraTS20_Training_333 ***-> 7728
# BraTS20_Training_205 ***-> 4059
# BraTS20_Training_289 ***-> 15
# BraTS20_Training_144 ***-> 61844
# BraTS20_Training_174 ***-> 24078
# BraTS20_Training_001 ***-> 26697
# BraTS20_Training_009 ***-> 40818
# BraTS20_Training_103 ***-> 34065
# BraTS20_Training_081 ***-> 7406
# BraTS20_Training_325 ***-> 120
# BraTS20_Training_338 ***-> 44668
# BraTS20_Training_120 ***-> 18099
# BraTS20_Training_161 ***-> 11066
# BraTS20_Training_285 ***-> 6023
# BraTS20_Training_306 ***-> 67
# BraTS20_Training_050 ***-> 33950
# BraTS20_Training_123 ***-> 26403
# BraTS20_Training_254 ***-> 55606
# BraTS20_Training_090 ***-> 10212
# BraTS20_Training_210 ***-> 49907
# BraTS20_Training_192 ***-> 17994
# BraTS20_Training_132 ***-> 22872
# BraTS20_Training_107 ***-> 9104
# BraTS20_Training_031 ***-> 20669
# BraTS20_Training_017 ***-> 7775
# BraTS20_Training_052 ***-> 10030
# BraTS20_Training_216 ***-> 15716
# BraTS20_Training_250 ***-> 2977
# BraTS20_Training_311 ***-> 507
# BraTS20_Training_185 ***-> 34030
# BraTS20_Training_281 ***-> 2
# BraTS20_Training_086 ***-> 84
# BraTS20_Training_129 ***-> 6879
# BraTS20_Training_091 ***-> 22185
# BraTS20_Training_072 ***-> 36046
# BraTS20_Training_171 ***-> 14296
# BraTS20_Training_184 ***-> 26194
# BraTS20_Training_147 ***-> 10007
# BraTS20_Training_295 ***-> 319
# BraTS20_Training_367 ***-> 19056
# BraTS20_Training_158 ***-> 1700
# BraTS20_Training_213 ***-> 14649
# BraTS20_Training_191 ***-> 83009
# BraTS20_Training_258 ***-> 25983
# BraTS20_Training_249 ***-> 18732
# BraTS20_Training_339 ***-> 36787
# BraTS20_Training_350 ***-> 37588
# BraTS20_Training_059 ***-> 1168
# BraTS20_Training_366 ***-> 18366
# BraTS20_Training_154 ***-> 30021
# BraTS20_Training_348 ***-> 37790
# BraTS20_Training_114 ***-> 22642
# BraTS20_Training_328 ***-> 952
# BraTS20_Training_365 ***-> 29439
# BraTS20_Training_064 ***-> 28985
# BraTS20_Training_203 ***-> 9210
# BraTS20_Training_277 ***-> 1401
# BraTS20_Training_299 ***-> 603
# BraTS20_Training_099 ***-> 1166
# BraTS20_Training_236 ***-> 40546
# BraTS20_Training_361 ***-> 124
# BraTS20_Training_048 ***-> 1723
# BraTS20_Training_349 ***-> 52441
# BraTS20_Training_071 ***-> 10432
# BraTS20_Training_029 ***-> 5472
# BraTS20_Training_359 ***-> 30654
# BraTS20_Training_237 ***-> 16481
# BraTS20_Training_251 ***-> 16574
# BraTS20_Training_023 ***-> 10688
# BraTS20_Training_346 ***-> 25191
# BraTS20_Training_353 ***-> 8367
# BraTS20_Training_332 ***-> 1880
# BraTS20_Training_368 ***-> 15462
# BraTS20_Training_198 ***-> 30318
# BraTS20_Training_308 ***-> 5019
# BraTS20_Training_312 ***-> 895
# BraTS20_Training_343 ***-> 32834
# BraTS20_Training_037 ***-> 12963
# BraTS20_Training_221 ***-> 60544
# BraTS20_Training_070 ***-> 12213
# BraTS20_Training_018 ***-> 1714
# BraTS20_Training_238 ***-> 34043
# BraTS20_Training_156 ***-> 25665
# BraTS20_Training_330 ***-> 33
# BraTS20_Training_131 ***-> 7875
# BraTS20_Training_015 ***-> 9067
# BraTS20_Training_087 ***-> 340
# BraTS20_Training_004 ***-> 15589
# BraTS20_Training_318 ***-> 1691
# BraTS20_Training_240 ***-> 4540
# BraTS20_Training_012 ***-> 5274
# BraTS20_Training_217 ***-> 8408
# BraTS20_Training_307 ***-> 8
# BraTS20_Training_054 ***-> 28368
# BraTS20_Training_008 ***-> 1090
# BraTS20_Training_084 ***-> 19995
# BraTS20_Training_181 ***-> 17585
# BraTS20_Training_223 ***-> 29855
# BraTS20_Training_165 ***-> 31863
# BraTS20_Training_005 ***-> 10679
# BraTS20_Training_369 ***-> 38902
# BraTS20_Training_159 ***-> 4048
# BraTS20_Training_358 ***-> 11764
# BraTS20_Training_157 ***-> 40314
# BraTS20_Training_197 ***-> 48266
# BraTS20_Training_267 ***-> 4793
# BraTS20_Training_190 ***-> 9096
# BraTS20_Training_058 ***-> 5217
# BraTS20_Training_268 ***-> 0
# BraTS20_Training_278 ***-> 1197
# BraTS20_Training_263 ***-> 3291
# BraTS20_Training_038 ***-> 23774
# BraTS20_Training_020 ***-> 25804
# BraTS20_Training_253 ***-> 14958
# BraTS20_Training_341 ***-> 6899
# BraTS20_Training_334 ***-> 10639
# BraTS20_Training_345 ***-> 5320
# BraTS20_Training_172 ***-> 8400
# BraTS20_Training_116 ***-> 19557
# BraTS20_Training_150 ***-> 46148
# BraTS20_Training_073 ***-> 8459
# BraTS20_Training_036 ***-> 4176
# BraTS20_Training_019 ***-> 10570
# BraTS20_Training_194 ***-> 34201
# BraTS20_Training_319 ***-> 143
# BraTS20_Training_315 ***-> 99
# BraTS20_Training_320 ***-> 7444
# BraTS20_Training_218 ***-> 61129
# BraTS20_Training_169 ***-> 25886
# BraTS20_Training_324 ***-> 91
# BraTS20_Training_089 ***-> 17528
# BraTS20_Training_074 ***-> 20884
# BraTS20_Training_168 ***-> 63881
# BraTS20_Training_331 ***-> 1842
# BraTS20_Training_003 ***-> 2879
# BraTS20_Training_234 ***-> 9927
# BraTS20_Training_296 ***-> 12983
# BraTS20_Training_024 ***-> 19625
# BraTS20_Training_321 ***-> 0
# BraTS20_Training_355 ***-> 56980
# BraTS20_Training_041 ***-> 14702
# BraTS20_Training_303 ***-> 1192
# BraTS20_Training_121 ***-> 16409
# BraTS20_Training_186 ***-> 47826
# BraTS20_Training_270 ***-> 57882
# BraTS20_Training_244 ***-> 27237
# BraTS20_Training_304 ***-> 74
# BraTS20_Training_256 ***-> 70447
# BraTS20_Training_363 ***-> 44300
# BraTS20_Training_102 ***-> 6674
# BraTS20_Training_233 ***-> 2419
# BraTS20_Training_139 ***-> 4374
# BraTS20_Training_136 ***-> 20763
# BraTS20_Training_357 ***-> 13196
# BraTS20_Training_344 ***-> 5909
# BraTS20_Training_039 ***-> 12249
# BraTS20_Training_292 ***-> 2832
# BraTS20_Training_286 ***-> 126
# BraTS20_Training_364 ***-> 26734
# BraTS20_Training_046 ***-> 1165
# BraTS20_Training_027 ***-> 13271
# BraTS20_Training_044 ***-> 1141
# BraTS20_Training_145 ***-> 17894
# BraTS20_Training_045 ***-> 40626
# BraTS20_Training_162 ***-> 32409
# BraTS20_Training_227 ***-> 4428
# BraTS20_Training_309 ***-> 1546
# BraTS20_Training_183 ***-> 48238
# BraTS20_Training_113 ***-> 3719
# BraTS20_Training_199 ***-> 31531
# BraTS20_Training_275 ***-> 355
# BraTS20_Training_035 ***-> 27897
# BraTS20_Training_219 ***-> 12838
# BraTS20_Training_351 ***-> 15427
# BraTS20_Training_214 ***-> 26666
# BraTS20_Training_224 ***-> 52401
# BraTS20_Training_225 ***-> 88072
# BraTS20_Training_133 ***-> 14690
# BraTS20_Training_287 ***-> 25996
# BraTS20_Training_212 ***-> 24076
# BraTS20_Training_242 ***-> 27352
# BraTS20_Training_134 ***-> 15957
# BraTS20_Training_101 ***-> 12343
# BraTS20_Training_326 ***-> 898
# BraTS20_Training_314 ***-> 2749
# BraTS20_Training_166 ***-> 46257
# BraTS20_Training_053 ***-> 8507
# BraTS20_Training_006 ***-> 28943
# BraTS20_Training_034 ***-> 21213
# BraTS20_Training_056 ***-> 23172
# BraTS20_Training_010 ***-> 6007
# BraTS20_Training_293 ***-> 35953
# BraTS20_Training_076 ***-> 10637
# BraTS20_Training_011 ***-> 7511
# BraTS20_Training_100 ***-> 29986
# BraTS20_Training_080 ***-> 6111
# BraTS20_Training_049 ***-> 6485
# BraTS20_Training_021 ***-> 2941
# BraTS20_Training_313 ***-> 782
# BraTS20_Training_096 ***-> 19546
# BraTS20_Training_173 ***-> 12893
# BraTS20_Training_119 ***-> 4091
# BraTS20_Training_164 ***-> 42421
# BraTS20_Training_235 ***-> 57740
# BraTS20_Training_220 ***-> 16996
# BraTS20_Training_097 ***-> 36051
# BraTS20_Training_092 ***-> 30258
# BraTS20_Training_200 ***-> 4140
# BraTS20_Training_305 ***-> 496
# BraTS20_Training_297 ***-> 0
# BraTS20_Training_262 ***-> 0
# BraTS20_Training_093 ***-> 23133
# BraTS20_Training_025 ***-> 17020
# BraTS20_Training_261 ***-> 7458
# BraTS20_Training_110 ***-> 2454
# BraTS20_Training_043 ***-> 2416
# BraTS20_Training_078 ***-> 4765
# BraTS20_Training_335 ***-> 295
# BraTS20_Training_323 ***-> 45
# BraTS20_Training_231 ***-> 36132
# BraTS20_Training_061 ***-> 6909
# BraTS20_Training_252 ***-> 37049
# BraTS20_Training_055 ***-> 9316
# BraTS20_Training_327 ***-> 14739
# BraTS20_Training_269 ***-> 41
# BraTS20_Training_082 ***-> 4227
# BraTS20_Training_248 ***-> 33368
# BraTS20_Training_167 ***-> 17414
# BraTS20_Training_245 ***-> 62457
# BraTS20_Training_310 ***-> 8
# BraTS20_Training_060 ***-> 14873
# BraTS20_Training_115 ***-> 13534
# BraTS20_Training_239 ***-> 5990
# BraTS20_Training_273 ***-> 1043
# BraTS20_Training_068 ***-> 13654
# BraTS20_Training_153 ***-> 12336
# BraTS20_Training_028 ***-> 8586
# BraTS20_Training_137 ***-> 37762
# BraTS20_Training_276 ***-> 2398
# BraTS20_Training_265 ***-> 15
# BraTS20_Training_143 ***-> 60278
# BraTS20_Training_271 ***-> 160
# BraTS20_Training_222 ***-> 8373
# BraTS20_Training_079 ***-> 1505
# BraTS20_Training_337 ***-> 26275
# BraTS20_Training_135 ***-> 42158
# BraTS20_Training_228 ***-> 9507
# BraTS20_Training_108 ***-> 8009
# BraTS20_Training_211 ***-> 16696
# BraTS20_Training_125 ***-> 29790
# BraTS20_Training_013 ***-> 4169
# BraTS20_Training_160 ***-> 31467
# BraTS20_Training_075 ***-> 34543
# BraTS20_Training_274 ***-> 73170
# BraTS20_Training_140 ***-> 26086
# BraTS20_Training_170 ***-> 12989
# BraTS20_Training_257 ***-> 10675
# BraTS20_Training_195 ***-> 17048
# BraTS20_Training_040 ***-> 23674
# BraTS20_Training_002 ***-> 5819
# BraTS20_Training_126 ***-> 14909
# BraTS20_Training_175 ***-> 73980
# BraTS20_Training_317 ***-> 3449
# BraTS20_Training_128 ***-> 1069
# BraTS20_Training_301 ***-> 3361
# BraTS20_Training_069 ***-> 15339
# BraTS20_Training_255 ***-> 85320
# BraTS20_Training_316 ***-> 1311
# BraTS20_Training_177 ***-> 952
# BraTS20_Training_291 ***-> 70
# BraTS20_Training_151 ***-> 37336
# BraTS20_Training_112 ***-> 45244
# BraTS20_Training_109 ***-> 21168
# BraTS20_Training_106 ***-> 37889
# BraTS20_Training_272 ***-> 119
# BraTS20_Training_360 ***-> 39433
# BraTS20_Training_138 ***-> 36966
# BraTS20_Training_241 ***-> 45989
# BraTS20_Training_146 ***-> 21573
# BraTS20_Training_290 ***-> 3927
# BraTS20_Training_232 ***-> 8954
# BraTS20_Training_032 ***-> 9591
# BraTS20_Training_155 ***-> 26107
# BraTS20_Training_246 ***-> 23329
# BraTS20_Training_007 ***-> 5765
# BraTS20_Training_065 ***-> 2852
# BraTS20_Training_294 ***-> 33
# BraTS20_Training_208 ***-> 37703
# BraTS20_Training_077 ***-> 7724
# BraTS20_Training_016 ***-> 15916
# BraTS20_Training_247 ***-> 49938
# BraTS20_Training_026 ***-> 22215
# BraTS20_Training_356 ***-> 19333
# BraTS20_Training_033 ***-> 16619
# BraTS20_Training_298 ***-> 61
# BraTS20_Training_105 ***-> 5576
# BraTS20_Training_206 ***-> 4825
# BraTS20_Training_142 ***-> 4569
# BraTS20_Training_322 ***-> 85
# BraTS20_Training_179 ***-> 33169
# BraTS20_Training_362 ***-> 35119
# BraTS20_Training_207 ***-> 24535
# BraTS20_Training_182 ***-> 8372
# BraTS20_Training_279 ***-> 72
# BraTS20_Training_329 ***-> 541
# BraTS20_Training_042 ***-> 18411
# BraTS20_Training_088 ***-> 8390
# BraTS20_Training_030 ***-> 5765
# BraTS20_Training_187 ***-> 38842
# BraTS20_Training_259 ***-> 10695
# BraTS20_Training_193 ***-> 28554
# BraTS20_Training_098 ***-> 22854
# BraTS20_Training_226 ***-> 38289
# BraTS20_Training_152 ***-> 28880
# BraTS20_Training_163 ***-> 43447
# BraTS20_Training_264 ***-> 0
# BraTS20_Training_229 ***-> 29352
# BraTS20_Training_122 ***-> 3365
# BraTS20_Training_347 ***-> 23891
# BraTS20_Training_302 ***-> 2043
